# %% [markdown]
# #Read Data

# %%
import json
import pandas as pd

# Initialize an empty list to hold all the data
all_data = []

# Read the data from data.txt
with open('detObj2.txt', 'r') as file:
    for line in file:
        # Parse each line as JSON
        data = json.loads(line.strip())
        
        # Check if 'time' and 'numObj' are in the data
        if 'time' not in data or 'numObj' not in data:
            continue  # Skip this entry if either key is missing
        
        time = data['time']
        numObj = data['numObj']
        
        # Iterate over the number of objects and construct a row for each object
        for i in range(numObj):
            row = {
                'time': time,
                'numObj': numObj,
                'x': data['x'][i] if 'x' in data else None,
                'y': data['y'][i] if 'y' in data else None,
                'z': data['z'][i] if 'z' in data else None,
                'doppler': data['doppler'][i] if 'doppler' in data else None,
                'snr': data['snr'][i] if 'snr' in data else None,
                'noise': data['noise'][i] if 'noise' in data else None
            }
            all_data.append(row)

# Convert the list of rows to a DataFrame
final_df = pd.DataFrame(all_data)

# print(final_df)
df =final_df

# %%
final_df
# Out:
#               time  numObj         x         y         z   doppler  snr  noise
# 0     1.720508e+09       7 -0.231777  0.000000  0.000000  3.404333  252    817
# 1     1.720508e+09       7  0.369629 -0.838489  0.000000  0.000000  976    153
# 2     1.720508e+09       7  0.000000  1.580081  1.206606  0.000000  169    792
# 3     1.720508e+09       7  0.000000  0.000000  2.273776  6.510218  873    184
# 4     1.720508e+09       7  1.128892  0.000000  0.000000  5.201660  153    768
# ...            ...     ...       ...       ...       ...       ...  ...    ...
# 1332  1.720508e+09      10  1.140569  0.000000  0.389578 -0.250449  874    846
# 1333  1.720508e+09      10  0.000000 -0.430833  0.000000 -0.088621  187    206
# 1334  1.720508e+09      10  0.000000  3.419633 -0.876571  0.560207  768    685
# 1335  1.720508e+09      10 -0.245411  0.000000 -0.147247  0.000000  210    371
# 1336  1.720508e+09      10  1.551342  0.000000  0.771389 -0.125224  749    894
#
# [1337 rows x 8 columns]

# %% [markdown]
# # ALL Data

# %%
import matplotlib.pyplot as plt
# Plotting the data in 3D
fig = plt.figure(figsize=(12, 8))
ax = fig.add_subplot(111, projection='3d')

# Plot x, y, z values
sc = ax.scatter(final_df['x'], final_df['y'], final_df['z'], c=final_df['time'], cmap='viridis')

# Add color bar to show the time progression
cbar = plt.colorbar(sc, ax=ax, pad=0.1)
cbar.set_label('Time')

ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
ax.set_title('3D Motion Over Time')

plt.show()

# %%
df

# %%
# show movie x,y

# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation
df=final_df

# Convert timestamp to datetime
df['time'] = pd.to_datetime(df['time'], unit='s')

# Sort the dataframe by timestamp
df = df.sort_values('time')
# Create the figure and axis
fig, ax = plt.subplots(figsize=(10, 6))

# Initialize an empty scatter plot
scat = ax.scatter([], [], s=50, c='b', alpha=0.5)

# Set the axis limits
ax.set_xlim(df['x'].min() - 1, df['x'].max() + 1)
ax.set_ylim(df['y'].min() - 1, df['y'].max() + 1)

# Set labels and title
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_title('Motion Over Time')

# Add a text annotation for the timestamp
time_text = ax.text(0.02, 0.95, '', transform=ax.transAxes)

# Animation update function
def update(frame):
   
    # Get data up to the current frame
    data = df.iloc[:frame + 1]
    
    # Update the scatter plot
    scat.set_offsets(data[['x', 'y']])
    
    # Update the timestamp text
    time_text.set_text(f'Time: {data.iloc[-1]["time"]}')
    
    return scat, time_text

# Create the animation
anim = FuncAnimation(fig, update, frames=len(df), interval=500, blit=True)

# Show the animation
plt.show()

# %%
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation, FFMpegWriter


# Create the animation
anim = FuncAnimation(fig, update, frames=len(df), interval=500, blit=True)

# Save the animation as a GIF file
anim.save('motion_animation.gif', writer='pillow', fps=30)

# Show the animation (optional, since we are saving it)
plt.show()

# %%
# show movie x,y,z togther

# %%
# Convert timestamp to datetime
df['time'] = pd.to_datetime(df['time'], unit='s')

# Sort the dataframe by timestamp
df = df.sort_values('time')

# Create the figure and 3D axis
fig = plt.figure(figsize=(10, 6))
ax = fig.add_subplot(111, projection='3d')

# Initialize an empty scatter plot
scat = ax.scatter([], [], [], s=50, c='b', alpha=0.5)

# Set the axis limits
ax.set_xlim(df['x'].min() - 1, df['x'].max() + 1)
ax.set_ylim(df['y'].min() - 1, df['y'].max() + 1)
ax.set_zlim(df['z'].min() - 1, df['z'].max() + 1)

# Set labels and title
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
ax.set_title('3D Motion Over Time')

# Add a text annotation for the timestamp
time_text = ax.text2D(0.02, 0.95, '', transform=ax.transAxes)

# Animation update function
def update(frame):
    # Get data up to the current frame
    data = df.iloc[:frame + 1]
    
    # Update the scatter plot
    scat._offsets3d = (data['x'], data['y'], data['z'])
    
    # Update the timestamp text
    time_text.set_text(f'Time: {data.iloc[-1]["time"]}')
    
    return scat, time_text

# Create the animation
anim = FuncAnimation(fig, update, frames=len(df), interval=500, blit=True)

# Show the animation
plt.show()

# %%
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation, FFMpegWriter


# Create the animation
anim = FuncAnimation(fig, update, frames=len(df), interval=500, blit=True)

# Save the animation as a GIF file
anim.save('motion_animation.gif', writer='pillow', fps=30)

# Show the animation (optional, since we are saving it)
plt.show()

# %%
# show movie x,y,z clear

# %%
# Convert timestamp to datetime
df['time'] = pd.to_datetime(df['time'], unit='s')

# Sort the dataframe by timestamp
df = df.sort_values('time')

# Create the figure and 3D axis
fig = plt.figure(figsize=(10, 6))
ax = fig.add_subplot(111, projection='3d')

# Set the axis limits
ax.set_xlim(df['x'].min() - 1, df['x'].max() + 1)
ax.set_ylim(df['y'].min() - 1, df['y'].max() + 1)
ax.set_zlim(df['z'].min() - 1, df['z'].max() + 1)

# Set labels and title
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
ax.set_title('3D Motion Over Time')

# Add a text annotation for the timestamp
time_text = ax.text2D(0.02, 0.95, '', transform=ax.transAxes)

# Animation update function
def update(frame):
    ax.clear()
    
    # Set the axis limits and labels again (since we cleared the axis)
    ax.set_xlim(df['x'].min() - 1, df['x'].max() + 1)
    ax.set_ylim(df['y'].min() - 1, df['y'].max() + 1)
    ax.set_zlim(df['z'].min() - 1, df['z'].max() + 1)
    ax.set_xlabel('X')
    ax.set_ylabel('Y')
    ax.set_zlabel('Z')
    ax.set_title('3D Motion Over Time')
    
    # Get data for the current frame
    data = df.iloc[frame]
    
    # Plot the current point
    ax.scatter(data['x'], data['y'], data['z'], s=50, c='b', alpha=0.5)
    
    # Update the timestamp text
    time_text = ax.text2D(0.02, 0.95, f'Time: {data["time"]}', transform=ax.transAxes)
    
    return ax, time_text

# Create the animation
anim = FuncAnimation(fig, update, frames=len(df), interval=500, blit=False)

# Show the animation
plt.show()

# Uncomment the following line to save the animation as a GIF
anim.save('3d_motion_animation.gif', writer='pillow', fps=2)

# %%
# x,y,z , show group same times:

# %%
final_df

# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation
from mpl_toolkits.mplot3d import Axes3D
df=final_df
# Assuming df is your DataFrame with columns 'time', 'x', 'y', 'z'
# Make sure 'time' is already converted to datetime and the DataFrame is sorted

# Group the data by unique timestamps
grouped = df.groupby('time')
unique_times = list(grouped.groups.keys())

# Create the figure and 3D axis
fig = plt.figure(figsize=(10, 6))
ax = fig.add_subplot(111, projection='3d')

# Set the axis limits
ax.set_xlim(df['x'].min() - 1, df['x'].max() + 1)
ax.set_ylim(df['y'].min() - 1, df['y'].max() + 1)
ax.set_zlim(df['z'].min() - 1, df['z'].max() + 1)

# Set labels and title
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
ax.set_title('3D Motion Over Time')

# Add a text annotation for the timestamp
time_text = ax.text2D(0.02, 0.95, '', transform=ax.transAxes)

# Animation update function
def update(frame):
#     ax.clear()
    
    # Set the axis limits and labels again (since we cleared the axis)
    ax.set_xlim(df['x'].min() - 1, df['x'].max() + 1)
    ax.set_ylim(df['y'].min() - 1, df['y'].max() + 1)
    ax.set_zlim(df['z'].min() - 1, df['z'].max() + 1)
    ax.set_xlabel('X')
    ax.set_ylabel('Y')
    ax.set_zlabel('Z')
    ax.set_title('3D Motion Over Time')
    
    # Get data for the current timestamp
    current_time = unique_times[frame]
    data = grouped.get_group(current_time)
    
    # Plot all points for the current timestamp
    ax.scatter(data['x'], data['y'], data['z'], s=50, c='b', alpha=0.5)
    
    # Update the timestamp text
    time_text = ax.text2D(0.02, 0.95, f'Time: {current_time}', transform=ax.transAxes)
    
    return ax, time_text

# Create the animation
anim = FuncAnimation(fig, update, frames=len(unique_times), interval=500, blit=False)

# Show the animation
plt.show()

# Save the animation as a GIF
anim.save('3d_motion_animation.gif', writer='pillow', fps=2)

# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation
import matplotlib.dates as mdates

# Assuming df is your DataFrame with columns 'time', 'x', 'y', 'z'
# Make sure 'time' is already converted to datetime and the DataFrame is sorted

# Create the figure and axes
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(12, 10), gridspec_kw={'height_ratios': [3, 1]})

# Set up the color map for z-values
norm = plt.Normalize(df['z'].min(), df['z'].max())
cmap = plt.get_cmap('viridis')

# Set labels and title
ax1.set_xlabel('X')
ax1.set_ylabel('Y')
ax1.set_title('2D Motion Over Time (Color = Z)')

ax2.set_xlabel('Time')
ax2.set_ylabel('Z')
ax2.set_title('Z Coordinate Over Time')

# Add colorbar
sm = plt.cm.ScalarMappable(cmap=cmap, norm=norm)
sm.set_array([])
cbar = fig.colorbar(sm, ax=ax1, label='Z Coordinate')

# Animation update function
def update(frame):
    ax1.clear()
    ax2.clear()
    
    # Set labels and title again (since we cleared the axes)
    ax1.set_xlabel('X')
    ax1.set_ylabel('Y')
    ax1.set_title('2D Motion Over Time (Color = Z)')
    ax2.set_xlabel('Time')
    ax2.set_ylabel('Z')
    ax2.set_title('Z Coordinate Over Time')
    
    # Plot all data points up to the current frame
    data = df.iloc[:frame+1]
    
    # 2D scatter plot with color representing Z
    scatter = ax1.scatter(data['x'], data['y'], c=data['z'], cmap=cmap, norm=norm)
    
    # Plot Z over time
    ax2.plot(data['time'], data['z'], 'b-')
    ax2.scatter(data['time'], data['z'], c=data['z'], cmap=cmap, norm=norm)
    
    # Adjust time axis for better visibility
    ax2.xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d %H:%M:%S'))
    plt.setp(ax2.xaxis.get_majorticklabels(), rotation=45, ha='right')
    
    # Add timestamp text
    ax1.text(0.02, 0.95, f'Time: {data.iloc[-1]["time"]}', transform=ax1.transAxes)
    
    fig.tight_layout()
    return ax1, ax2

# Create the animation
anim = FuncAnimation(fig, update, frames=len(df), interval=500, blit=False)

# Show the animation
plt.show()

# Save the animation as a GIF
anim.save('2d1_motion_animation.gif', writer='pillow', fps=2)

# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.animation import PillowWriter
from mpl_toolkits.mplot3d import Axes3D
import numpy as np

# Convert timestamp to datetime
df['time'] = pd.to_datetime(df['time'], unit='s')

# Sort the dataframe by timestamp
df = df.sort_values('time')

# Create the figure and 3D axis
fig = plt.figure(figsize=(12, 10))
ax = fig.add_subplot(111, projection='3d')

# Set labels and title
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
ax.set_title('3D Trajectory Over Time')

# Create a color map based on time
color_map = plt.cm.viridis
colors = color_map(np.linspace(0, 1, len(df)))

# Set consistent axis limits
ax.set_xlim(df['x'].min(), df['x'].max())
ax.set_ylim(df['y'].min(), df['y'].max())
ax.set_zlim(df['z'].min(), df['z'].max())

# Add color bar
scatter = ax.scatter([], [], [], c=[], cmap=color_map)
fig.colorbar(scatter, ax=ax, label='Time Progression')

# Initialize the timestamp text
time_text = ax.text2D(0.05, 0.95, '', transform=ax.transAxes)

# Create PillowWriter
writer = PillowWriter(fps=10)

# Start the writer
with writer.saving(fig, "3d_trajectory_animation.gif", dpi=100):
    for i in range(len(df)):
        # Get data up to the current frame
        data = df.iloc[:i+1]
        
        # Update scatter plot
        scatter._offsets3d = (data['x'], data['y'], data['z'])
        scatter.set_array(np.linspace(0, 1, len(data)))
        
        # Update timestamp text
        time_text.set_text(f'Time: {data.iloc[-1]["time"]}')
        
        # Draw the frame
        fig.canvas.draw()
        
        # Grab the frame
        writer.grab_frame()

plt.close(fig)
print("Animation saved as 3d_trajectory_animation.gif")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 8
#       5 import numpy as np
#       7 # Convert timestamp to datetime
# ----> 8 df['time'] = pd.to_datetime(df['time'], unit='s')
#      10 # Sort the dataframe by timestamp
#      11 df = df.sort_values('time')
#
# NameError: name 'df' is not defined

# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.animation import PillowWriter
import numpy as np




# Convert timestamp to datetime
df['time'] = pd.to_datetime(df['time'], unit='s')

# Sort the dataframe by timestamp
df = df.sort_values('time')

# Create the figure and 3D axis
fig = plt.figure(figsize=(12, 10))

# 3D Trajectory
ax = fig.add_subplot(221, projection='3d')
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
ax.set_title('3D Trajectory Over Time')

color_map = plt.cm.viridis
colors = color_map(np.linspace(0, 1, len(df)))

ax.scatter(df['x'], df['y'], df['z'], c=colors, cmap=color_map)
fig.colorbar(ax.scatter(df['x'], df['y'], df['z'], c=colors, cmap=color_map), ax=ax, label='Time Progression')

# X-Y Projection
ax_xy = fig.add_subplot(222)
ax_xy.set_xlabel('X')
ax_xy.set_ylabel('Y')
ax_xy.set_title('X-Y Projection')
ax_xy.scatter(df['x'], df['y'], c=colors, cmap=color_map)
fig.colorbar(ax_xy.scatter(df['x'], df['y'], c=colors, cmap=color_map), ax=ax_xy, label='Time Progression')

# X-Z Projection
ax_xz = fig.add_subplot(223)
ax_xz.set_xlabel('X')
ax_xz.set_ylabel('Z')
ax_xz.set_title('X-Z Projection')
ax_xz.scatter(df['x'], df['z'], c=colors, cmap=color_map)
fig.colorbar(ax_xz.scatter(df['x'], df['z'], c=colors, cmap=color_map), ax=ax_xz, label='Time Progression')

# Y-Z Projection
ax_yz = fig.add_subplot(224)
ax_yz.set_xlabel('Y')
ax_yz.set_ylabel('Z')
ax_yz.set_title('Y-Z Projection')
ax_yz.scatter(df['y'], df['z'], c=colors, cmap=color_map)
fig.colorbar(ax_yz.scatter(df['y'], df['z'], c=colors, cmap=color_map), ax=ax_yz, label='Time Progression')

plt.tight_layout()
plt.savefig("radar_projections.png")
plt.show()
print("Projections saved as radar_projections.png")

# Create an animated GIF for the 3D trajectory
fig = plt.figure(figsize=(12, 10))
ax = fig.add_subplot(111, projection='3d')
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
ax.set_title('3D Trajectory Over Time')

color_map = plt.cm.viridis
colors = color_map(np.linspace(0, 1, len(df)))

ax.set_xlim(df['z'].min(), df['z'].max())
ax.set_ylim(df['x'].min(), df['x'].max())
ax.set_zlim(df['y'].min(), df['y'].max())

scatter = ax.scatter([], [], [], c=[], cmap=color_map)
fig.colorbar(scatter, ax=ax, label='Time Progression')

time_text = ax.text2D(0.05, 0.95, '', transform=ax.transAxes)

writer = PillowWriter(fps=10)

with writer.saving(fig, "3d_trajectory_animation.gif", dpi=100):
    for i in range(len(df)):
        data = df.iloc[:i+1]
        scatter._offsets3d = (data['x'], data['y'], data['z'])
        scatter.set_array(np.linspace(0, 1, len(data)))
        time_text.set_text(f'Time: {data.iloc[-1]["time"]}')
        fig.canvas.draw()
        writer.grab_frame()

plt.close(fig)
print("Animation saved as 3d_trajectory_animation.gif")
# Out:
# C:\Users\RGS\AppData\Local\Temp\ipykernel_13272\3571002649.py:28: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   ax.scatter(df['x'], df['y'], df['z'], c=colors, cmap=color_map)
# C:\Users\RGS\AppData\Local\Temp\ipykernel_13272\3571002649.py:29: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   fig.colorbar(ax.scatter(df['x'], df['y'], df['z'], c=colors, cmap=color_map), ax=ax, label='Time Progression')
# C:\Users\RGS\AppData\Local\Temp\ipykernel_13272\3571002649.py:36: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   ax_xy.scatter(df['x'], df['y'], c=colors, cmap=color_map)
# C:\Users\RGS\AppData\Local\Temp\ipykernel_13272\3571002649.py:37: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   fig.colorbar(ax_xy.scatter(df['x'], df['y'], c=colors, cmap=color_map), ax=ax_xy, label='Time Progression')
# ...

# %%
import pandas as pd
from sklearn.cluster import KMeans
from sklearn.metrics.pairwise import cosine_similarity
import pandas as pd
from sklearn.cluster import DBSCAN
import numpy as np
# Sort the DataFrame by time
df = df.sort_values('time')

# Create a feature matrix for clustering (use 'x', 'y', 'z')
features = df[['x', 'y', 'z']]

# Apply DBSCAN clustering
dbscan = DBSCAN(eps=0.1, min_samples=5)  # Adjust eps and min_samples as needed
cluster_labels = dbscan.fit_predict(features)

# Add cluster labels to the DataFrame
df['cluster'] = cluster_labels

# %%
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation
from mpl_toolkits.mplot3d import Axes3D

# Group the data by unique timestamps
grouped = df.groupby('time')
unique_times = list(grouped.groups.keys())

# Create the figure and 3D axis
fig = plt.figure(figsize=(10, 6))
ax = fig.add_subplot(111, projection='3d')

# Set the axis limits
ax.set_xlim(df['x'].min() - 1, df['x'].max() + 1)
ax.set_ylim(df['y'].min() - 1, df['y'].max() + 1)
ax.set_zlim(df['z'].min() - 1, df['z'].max() + 1)

# Set labels and title
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
ax.set_title('3D Motion Over Time')

# Add a text annotation for the timestamp
time_text = ax.text2D(0.02, 0.95, '', transform=ax.transAxes)

# Define a color map for clusters
unique_clusters = df['cluster'].nunique()
colors = plt.cm.get_cmap('viridis', unique_clusters)

# Animation update function
def update(frame):
    ax.clear()
    
    # Set the axis limits and labels again (since we cleared the axis)
    ax.set_xlim(df['x'].min() - 1, df['x'].max() + 1)
    ax.set_ylim(df['y'].min() - 1, df['y'].max() + 1)
    ax.set_zlim(df['z'].min() - 1, df['z'].max() + 1)
    ax.set_xlabel('X')
    ax.set_ylabel('Y')
    ax.set_zlabel('Z')
    ax.set_title('3D Motion Over Time')
    
    # Get data for the current timestamp
    current_time = unique_times[frame]
    data = grouped.get_group(current_time)
    
    # Plot all points for the current timestamp, colored by cluster
    scatter = ax.scatter(data['x'], data['y'], data['z'], c=data['cluster'], cmap=colors, s=50, alpha=0.5)
    
    # Update the timestamp text
    time_text.set_text(f'Time: {current_time}')
    
    return scatter, time_text

# Create the animation
anim = FuncAnimation(fig, update, frames=len(unique_times), interval=500, blit=False)

# Show the animation
plt.show()

# Save the animation as a
# Out:
# C:\Users\RGS\AppData\Local\Temp\ipykernel_16216\1639843841.py:29: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   colors = plt.cm.get_cmap('viridis', unique_clusters)

# %%
# Group the data by unique timestamps
grouped = df.groupby('time')
unique_times = list(grouped.groups.keys())

# Create the figure and 3D axis
fig = plt.figure(figsize=(10, 6))
ax = fig.add_subplot(111, projection='3d')

# Set the axis limits
ax.set_xlim(df['x'].min() - 1, df['x'].max() + 1)
ax.set_ylim(df['y'].min() - 1, df['y'].max() + 1)
ax.set_zlim(df['z'].min() - 1, df['z'].max() + 1)

# Set labels and title
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
ax.set_title('3D Motion Over Time')

# Add a text annotation for the timestamp
time_text = ax.text2D(0.02, 0.95, '', transform=ax.transAxes)

# Define a color map for clusters
n_clusters = 3
colors = plt.cm.get_cmap('viridis', n_clusters)
# Out:
# C:\Users\RGS\AppData\Local\Temp\ipykernel_16216\452781457.py:25: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   colors = plt.cm.get_cmap('viridis', n_clusters)

# %%
# Group the data by unique timestamps
grouped = df.groupby('time')
unique_times = list(grouped.groups.keys())

# Create the figure and 3D axis
fig = plt.figure(figsize=(10, 6))
ax = fig.add_subplot(111, projection='3d')

# Set the axis limits
ax.set_xlim(df['x'].min() - 1, df['x'].max() + 1)
ax.set_ylim(df['y'].min() - 1, df['y'].max() + 1)
ax.set_zlim(df['z'].min() - 1, df['z'].max() + 1)

# Set labels and title
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
ax.set_title('3D Motion Over Time')

# Add a text annotation for the timestamp
time_text = ax.text2D(0.02, 0.95, '', transform=ax.transAxes)

# Define a color map for clusters
n_clusters = 3
colors = plt.cm.get_cmap('viridis', n_clusters)
# Out:
# C:\Users\RGS\AppData\Local\Temp\ipykernel_16216\452781457.py:25: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   colors = plt.cm.get_cmap('viridis', n_clusters)

# %%
# Animation update function
def update(frame):
    ax.clear()
    
    # Set the axis limits and labels again (since we cleared the axis)
    ax.set_xlim(df['x'].min() - 1, df['x'].max() + 1)
    ax.set_ylim(df['y'].min() - 1, df['y'].max() + 1)
    ax.set_zlim(df['z'].min() - 1, df['z'].max() + 1)
    ax.set_xlabel('X')
    ax.set_ylabel('Y')
    ax.set_zlabel('Z')
    ax.set_title('3D Motion Over Time')
    
    # Get data for the current timestamp
    current_time = unique_times[frame]
    data = grouped.get_group(current_time)
    
    # Perform KMeans clustering
    kmeans = KMeans(n_clusters=n_clusters, random_state=0)
    try:
        data['cluster'] = kmeans.fit_predict(data[['x', 'y', 'z']])
    except Exception as e:
        print(f"Clustering failed for frame {frame}: {e}")
        data['cluster'] = np.zeros(len(data))  # Assign all to one cluster if clustering fails
    
    # Plot all points for the current timestamp, colored by cluster
    scatter = ax.scatter(data['x'], data['y'], data['z'], c=data['cluster'], cmap=colors, s=50, alpha=0.5)
    
    # Update the timestamp text
    time_text.set_text(f'Time: {current_time}')
    
    return scatter, time_text

# Create the animation
anim = FuncAnimation(fig, update, frames=len(unique_times), interval=500, blit=False)

# Show the animation
plt.show()

# %%
# Save the animation as a GIF
anim.save('3d_motion_animation.gif', writer='pillow', fps=2)
# Out:
# C:\Users\RGS\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\RGS\AppData\Local\Temp\ipykernel_16216\1752242866.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['cluster'] = np.zeros(len(data))  # Assign all to one cluster if clustering fails
# C:\Users\RGS\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# ...

# %%
df
# Out:
#               time  numObj         x         y         z   doppler  snr  noise
# 0     1.720508e+09       7 -0.231777  0.000000  0.000000  3.404333  252    817
# 1     1.720508e+09       7  0.369629 -0.838489  0.000000  0.000000  976    153
# 2     1.720508e+09       7  0.000000  1.580081  1.206606  0.000000  169    792
# 3     1.720508e+09       7  0.000000  0.000000  2.273776  6.510218  873    184
# 4     1.720508e+09       7  1.128892  0.000000  0.000000  5.201660  153    768
# ...            ...     ...       ...       ...       ...       ...  ...    ...
# 1329  1.720508e+09      10  0.000000  1.126166  0.000000 -1.325221  185    326
# 1331  1.720508e+09      10  1.079810  0.000000 -0.049082  0.000000  185    157
# 1333  1.720508e+09      10  0.000000 -0.430833  0.000000 -0.088621  187    206
# 1327  1.720508e+09      10 -0.084531  0.000000 -0.362663  0.000000  156    393
# 1336  1.720508e+09      10  1.551342  0.000000  0.771389 -0.125224  749    894
#
# [1337 rows x 8 columns]

# %%
import os
os.environ["KMP_INIT_AT_FORK"] = "FALSE"

import pandas as pd
from sklearn.cluster import KMeans
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation
from mpl_toolkits.mplot3d import Axes3D

# %%
# Ensure the DataFrame is sorted by time
df['time'] = pd.to_datetime(df['time'], unit='s')
df = df.sort_values('time')

# %%
# Group the data by unique timestamps
grouped = df.groupby('time')
unique_times = list(grouped.groups.keys())

# Create the figure and 3D axis
fig = plt.figure(figsize=(10, 6))
ax = fig.add_subplot(111, projection='3d')

# Set labels and title
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
ax.set_title('3D Motion Over Time')

# Add a text annotation for the timestamp
time_text = ax.text2D(0.02, 0.95, '', transform=ax.transAxes)

# Define a color map for clusters
n_clusters = 3
colors = plt.cm.get_cmap('viridis', n_clusters)
# Out:
# C:\Users\RGS\AppData\Local\Temp\ipykernel_16216\1113144805.py:20: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   colors = plt.cm.get_cmap('viridis', n_clusters)

# %%
import os
os.environ["KMP_INIT_AT_FORK"] = "FALSE"  # Disable OpenMP threading

import pandas as pd
from sklearn.cluster import KMeans
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation
from mpl_toolkits.mplot3d import Axes3D


# Ensure the DataFrame is sorted by time
df['time'] = pd.to_datetime(df['time'], unit='s')
df = df.sort_values('time')

# Group the data by unique timestamps
grouped = df.groupby('time')
unique_times = list(grouped.groups.keys())

# Create the figure and 3D axis
fig = plt.figure(figsize=(10, 6))
ax = fig.add_subplot(111, projection='3d')

# Set labels and title
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
ax.set_title('3D Motion Over Time')

# Add a text annotation for the timestamp
time_text = ax.text2D(0.02, 0.95, '', transform=ax.transAxes)

# Define a color map for clusters
n_clusters = 3
colors = plt.cm.get_cmap('viridis', n_clusters)

# Animation update function
def update(frame):
    ax.clear()
    
    # Set the axis limits and labels again (since we cleared the axis)
    ax.set_xlim(df['x'].min() - 1, df['x'].max() + 1)
    ax.set_ylim(df['y'].min() - 1, df['y'].max() + 1)
    ax.set_zlim(df['z'].min() - 1, df['z'].max() + 1)
    ax.set_xlabel('X')
    ax.set_ylabel('Y')
    ax.set_zlabel('Z')
    ax.set_title('3D Motion Over Time')
    
    # Get data for the current timestamp
    current_time = unique_times[frame]
    data = grouped.get_group(current_time)
    
    # Perform KMeans clustering if there are enough data points
    if len(data) >= n_clusters:
        kmeans = KMeans(n_clusters=n_clusters, random_state=0)
        data['cluster'] = kmeans.fit_predict(data[['x', 'y', 'z']])
    else:
        data['cluster'] = [0] * len(data)  # Assign all points to a single cluster
    
    # Plot all points for the current timestamp, colored by cluster
    scatter = ax.scatter(data['x'], data['y'], data['z'], c=data['cluster'], cmap=colors, s=50, alpha=0.5)
    
    # Update the timestamp text
    time_text.set_text(f'Time: {current_time}')
    
    return scatter, time_text

# Create the animation
anim = FuncAnimation(fig, update, frames=len(unique_times), interval=500, blit=False)

# Show the animation
plt.show()

# Save the animation as a GIF
try:
    anim.save('3d_motion_animation.gif', writer='pillow', fps=2)
except Exception as e:
    print(f"Error saving animation: {e}")
# Out:
# C:\Users\RGS\AppData\Local\Temp\ipykernel_16216\3424225286.py:35: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   colors = plt.cm.get_cmap('viridis', n_clusters)
# Error saving animation: list index out of range
# C:\Users\RGS\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
